# %%
# import packages
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
# reading the .csv file using it's URL
avg_month_precip = pd.read_csv("https://ndownloader.figshare.com/files/12710618")

# %%
# viewing the data downloaded
avg_month_precip
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 2     Mar    1.85  Spring
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring
# 5    June    2.02  Summer
# 6    July    1.93  Summer
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
avg_month_precip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   months   12 non-null     object
#  1   precip   12 non-null     float64
#  2   seasons  12 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 416.0+ bytes

# %%
# plotting the data
f, ax = plt.subplots()
avg_month_precip.plot(x="months", y="precip",
                     title="Precipitation (mm) for one year",
                     ax=ax)

ax.set(xlabel='Month',
      ylabel='Precipitation (mm)')
plt.show()

# %% [markdown]
# Challenge 1:
#     Determining the 'type' of data stored in avg_month_precip

# %%
avg_month_precip.dtypes
# Out:
# months      object
# precip     float64
# seasons     object
# dtype: object

# %%
# challenge 2:
# plotting a bar chat with mulitple bar colors
f, ax = plt.subplots()
default_color=[1]
avg_month_precip.plot(kind="barh",
                        x="months",
                       y="precip",
                    
                       title="Precipitation (mm) for one Year",
                       ax=ax)

ax.set(xlabel='Month',
      ylabel='Precipitation (mm)')
plt.show()

# %%
# open temperature data for Miami, florida 
miami_temp_url = "https://www.ncdc.noaa.gov/cag/city/time-series/USW00012839-tmax-12-12-1895-2020.csv"

miami_temp = pd.read_csv(miami_temp_url)
miami_temp
# Out:
#                         Miami  Florida   Maximum Temperature  \
# 0   Units: Degrees Fahrenheit      NaN                   NaN
# 1                Missing: -99      NaN                   NaN
# 2                        Date    Value                   NaN
# 3                      194812     83.7                   NaN
# 4                      194912     83.1                   NaN
# ..                        ...      ...                   ...
# 71                     201612     84.6                   NaN
# 72                     201712     85.9                   NaN
# 73                     201812     84.5                   NaN
# 74                     201912     85.9                   NaN
# 75                     202012     85.8                   NaN
#
#      January-December
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 71                NaN
# 72                NaN
# ...

# %%
# lets make copies before editing
miami_temp_data = miami_temp.copy()

# %%
# removing the first 3 rows and missing data
miami_temp_data = pd.read_csv(miami_temp_url, skiprows=3, na_values=-99)

# viewing the first 4 rows of the data
miami_temp_data.head(4)
# Out:
#      Date  Value
# 0  194812   83.7
# 1  194912   83.1
# 2  195012   82.3
# 3  195112   82.7

# %%
# plotting the data
f, ax = plt.subplots()
miami_temp_data.plot(x="Date",
                        y="Value",
                        title="Temperature (Fahrenheit) Data for Miami, FL",
                        ax=ax)
ax.set(xlabel='Data',
       ylabel='Tempearture (Fahrenheit)')
plt.show()

# %% [markdown]
# Challenge

# %%
# open temperature data for Seatle, Washington
montogmery_temp_url = "https://www.ncdc.noaa.gov/cag/city/time-series/USW00013895-tmax-1-5-1895-2020.csv"

montogmery_temp = pd.read_csv(montogmery_temp_url)
montogmery_temp
# Out:
#                    Montgomery  Alabama   Maximum Temperature   May
# 0   Units: Degrees Fahrenheit      NaN                   NaN   NaN
# 1                Missing: -99      NaN                   NaN   NaN
# 2                        Date    Value                   NaN   NaN
# 3                      194805     88.2                   NaN   NaN
# 4                      194905     88.0                   NaN   NaN
# ..                        ...      ...                   ...   ...
# 71                     201605     85.0                   NaN   NaN
# 72                     201705     84.1                   NaN   NaN
# 73                     201805     87.9                   NaN   NaN
# 74                     201905     88.7                   NaN   NaN
# 75                     202005     85.0                   NaN   NaN
#
# [76 rows x 4 columns]

# %%
# dropping the metadata
montogmery_temp = pd.read_csv(montogmery_temp_url,
                          skiprows=3,
                          na_values=-99)
montogmery_temp
# Out:
#       Date  Value
# 0   194805   88.2
# 1   194905   88.0
# 2   195005   87.5
# 3   195105   87.0
# 4   195205   85.8
# ..     ...    ...
# 68  201605   85.0
# 69  201705   84.1
# 70  201805   87.9
# 71  201905   88.7
# 72  202005   85.0
#
# [73 rows x 2 columns]

# %%
# plotting the data
f, ax = plt.subplots()
montogmery_temp.plot(x="Date",
                        y="Value",
                        title="Temperature (Fahrenheit) Data for Montogmery,AL",
                        ax=ax)
ax.set(xlabel='Data',
       ylabel='Tempearture (Fahrenheit)')
plt.show()

# %% [markdown]
# Challenge

# %%
# Download greenhouse gas CO2 data
import urllib.request

greenhouse_gas_url = "ftp://aftp.cmdl.noaa.gov/data/trace_gases/co2/in-situ/surface/brw/co2_brw_surface-insitu_1_ccgg_MonthlyData.txt"

urllib.request.urlretrieve(url=greenhouse_gas_url,
                           filename="co2-emissions-barrow.csv")
# Out:
# ('co2-emissions-barrow.csv', <email.message.Message at 0x1ffdc0cfbe0>)

# %%
#viewing and cleaning data using pandas data frame and skiprows and na_values paramter
alaska_co2_emission = pd.read_csv('co2-emissions-barrow.csv', sep=' ',
                                 skiprows=149,
                                 na_values=-999.99)
alaska_co2_emission
# Out:
#     site_code  year  month  day  hour  minute  second  time_decimal   value  \
# 0         BRW  1973      1    1     0       0       0   1973.000000     NaN
# 1         BRW  1973      2    1     0       0       0   1973.084932     NaN
# 2         BRW  1973      3    1     0       0       0   1973.161644     NaN
# 3         BRW  1973      4    1     0       0       0   1973.246575     NaN
# 4         BRW  1973      5    1     0       0       0   1973.328767     NaN
# ..        ...   ...    ...  ...   ...     ...     ...           ...     ...
# 583       BRW  2021      8    1     0       0       0   2021.580822  405.03
# 584       BRW  2021      9    1     0       0       0   2021.665753  408.00
# 585       BRW  2021     10    1     0       0       0   2021.747945  414.07
# 586       BRW  2021     11    1     0       0       0   2021.832877  419.81
# 587       BRW  2021     12    1     0       0       0   2021.915068  423.29
#
# ...

# %%
# plotting the data
f, ax = plt.subplots()
alaska_co2_emission.plot(x="time_decimal",
                        y="value",
                        title="Plot: CO2 - Barrow, AK",
                        ax=ax)
ax.set(xlabel='Date',
       ylabel='CO2')
plt.show()
